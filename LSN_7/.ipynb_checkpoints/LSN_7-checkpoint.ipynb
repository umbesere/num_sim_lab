# %%
import numpy as np 
import matplotlib.pyplot as plt
from statistics import mean

# %% [markdown]
# # LSN_7

# %% [markdown]
# ### EX07_1

# %%
# %%time
en_solid, pres_solid = np.loadtxt('instant_values/instasolid.txt', usecols=(1,2), unpack=True)
en_liquid, pres_liquid = np.loadtxt('instant_values/instaliquid.txt', usecols=(1,2), unpack=True)
en_gas, pres_gas = np.loadtxt('instant_values/instagas.txt', usecols=(1,2), unpack=True)
en = [en_solid, en_liquid, en_gas]
pres = [pres_solid, pres_liquid, pres_gas]
titles = ['SOLID','LIQUID','GAS']
phases = ['solid','liquid','gas']
quantities = ['energy','pressure']
# Out:
# CPU times: user 5.84 s, sys: 36.2 ms, total: 5.88 s
# Wall time: 5.85 s

# %%
fig, axx = plt.subplots(1, 2,figsize=(12, 6))
t = np.linspace(0, len(en_solid), len(en_solid))

for i,ax in enumerate(axx):
    ax.plot(t, en[0], label = quantities[i]+'_'+phases[0])
    ax.plot(t, en[1], label = quantities[i]+'_'+phases[1])
    ax.plot(t, en[2], label = quantities[i]+'_'+phases[2])
    ax.set_xlabel("simulation_time")
    ax.set_ylabel(phases[i]+"[LJ units]")
    #ax.set_ylim(-10, 10)
    ax.legend(loc='best')
    ax.set_title(quantities[i].upper())
    ax.grid()

# %%
def auto(vect, tmax):
    auto = []
    for t in range(tmax):
        sum1 = 0
        sum2 = 0
        sum3 = 0
        sum4 = 0
        sum5 = 0
        for tt in range(tmax-t):
            sum1 = sum1 + vect[tt]*vect[tt+t]
            sum2 = sum2 + vect[tt]
            sum3 = sum3 + vect[tt+t]
        for tt in range(tmax):
            sum4 = sum4 + vect[tt]
            sum5 = sum5 + vect[tt]*vect[tt]
        auto.append( (sum1/(tmax-t) - sum2*sum3/(tmax-t)**2) / (sum5/tmax - (sum4/tmax)**2) )
    return auto

# %%
def auto(vect, tn):
    tmax = len(vect)
    auto = []
    for t in range(tn):
        sum1 = sum1 + vect[tt]*vect[tt+t]
        
        sum1 = np.sum([ vect[tt]*vect[tt+t] for tt in range(0,tmax-t+1)])
        sum2 = np.sum(vect[0:tmax-t])
        sum3 = np.sum(vect[t:tmax])
        sum4 = np.sum(vect[0:tmax])
        sum5 = np.sum([i**2 for i in vect[0:tmax]])
        auto.append( (sum1/(tmax-t) - sum2*sum3/(tmax-t)**2) / (sum5/tmax - (sum4/tmax)**2) )
    return auto

# %%
def auto(vect, tn):
    auto = []
    tmax = len(vect)-1
    sum1 = np.sum([ vect[tt]*vect[tt] for tt in range(0,tmax+1)])
    sum4 = np.sum(vect[0:tmax])
    sum5 = np.sum([i**2 for i in vect[0:tmax]])
    sum2 = np.sum(vect[0:tmax])
    sum3 = sum2
    auto.append( (sum5/tmax - sum2*sum3/tmax**2) / (sum5/tmax - (sum4/tmax)**2) )
    for t in range(1,tn):
        sum1 = np.sum([ vect[tt]*vect[tt+t] for tt in range(0,tmax-t+1)])
        sum2 = sum2 - vect[tmax-t+1]
        sum3 = sum3 - vect[t-1]
        auto.append( (sum1/(tmax-t) - sum2*sum3/(tmax-t)**2) / (sum5/tmax - (sum4/tmax)**2) )
    return auto

# %%
# %%time
tmax = 1000
auto_en = []
auto_pres = []
for i in range(3):
    auto_en.append(auto(en[i], tmax))
    auto_pres.append(auto(pres[i], tmax))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-40-a7f895b5ae79> in auto(vect, tn)
#       9     auto.append( (sum5/tmax - sum2*sum3/tmax**2) / (sum5/tmax - (sum4/tmax)**2) )
#      10     for t in range(1,tn):
# ---> 11         sum1 = np.sum([ vect[tt]*vect[tt+t] for tt in range(0,tmax-t+1)])
#      12         sum2 = sum2 - vect[tmax-t+1]
#      13         sum3 = sum3 - vect[t-1]
#
# KeyboardInterrupt:

# %%
fig, axx = plt.subplots(1, 3,figsize=(18, 6))
scales = [1000,1000,1000]
for i,ax in enumerate(axx):
    ax.plot(t[:scales[i]], auto_en[i][:scales[i]], label = "energy")
    ax.plot(t[:scales[i]], auto_pres[i][:scales[i]], label = "pressure")
    #ax.set_yscale('log')
    ax.set_xlabel('time')
    ax.set_ylabel('autocorrelation')
    ax.set_title(titles[i]+' AUTOCORRELATION FUNCTION')
    ax.legend()
    ax.grid()

# %%
def sigma(vect, length):
    nblock = int(len(vect)/length)
    av = [mean(vect[int(k*length):int((k+1)*length-1)]) for k in range(nblock)]
    av2 = [mean([i**2 for i in vect[int(k*length):int((k+1)*length-1)]]) for k in range(nblock)]
    return np.sqrt((mean(av2) - mean(av)**2)/nblock)

# %%
# %%time
nbins=10
#Ls = np.linspace(10, 5000, nbins)
Ls = [10, 50, 100, 200, 400, 500, 1000, 2000, 4000, 5000, 10000, 20000, 40000, 50000, 100000, 200000, 400000, 500000]
sigma_en = []
sigma_pres = []
for i in range(3):
    sigma_en.append([sigma(en[i],l) for l in Ls])
    sigma_pres.append([sigma(pres[i],l) for l in Ls])
# Out:
# CPU times: user 2min 16s, sys: 0 ns, total: 2min 16s
# Wall time: 2min 16s

# %%
fig, axx = plt.subplots(1,3,figsize=(18,6))
ylims = [0.5,0.5, 0.1]
for i,ax in enumerate(axx):
    ax.plot(Ls, sigma_en[i], label = 'sigma_en')
    ax.plot(Ls, sigma_pres[i], label = 'sigma_pres')    
    ax.set_xlabel('block_length')
    ax.set_ylabel('blocking_sigma')
    ax.set_title(titles[i]+' - BLOCKING_ERROR VS BLOCK_LENGTH')
    ax.set_ylim(0, ylims[i])
    ax.grid()
    ax.legend()

# %% [markdown]
# ### EX07_4

# %%
gofr_monte = [[],[],[]]
gofr_dyn = [[],[],[]]
en = [[],[],[]]
pres = [[],[],[]]
for i,ph in enumerate(phases):
    r, gofr, err_gofr = np.loadtxt('gave/gave.'+ph+'.montecarlo.out', usecols=(0,1,2), unpack=True)
    gofr_monte[i].append(r)
    gofr_monte[i].append(gofr)
    gofr_monte[i].append(err_gofr)
    r, gofr, err_gofr = np.loadtxt('gave/gave.'+ph+'.moldyn.out', usecols=(0,1,2), unpack=True)
    gofr_dyn[i].append(r)
    gofr_dyn[i].append(gofr)
    gofr_dyn[i].append(err_gofr)
    iblock, var, err_var = np.loadtxt(ph+'/output.epot.0', usecols=(0,2,3), unpack=True)
    en[i].append(iblock)
    en[i].append(var)
    en[i].append(err_var)
    iblock, var, err_var = np.loadtxt(ph+'/output.pres.0', usecols=(0,2,3), unpack=True)
    pres[i].append(iblock)
    pres[i].append(var)
    pres[i].append(err_var)

# %%
fig, axx = plt.subplots(2,3,figsize=(18,12))
axx = axx.reshape(-1)
labels = ['energy','pressure']

var = [en, pres]

for i in range(6):
    ax = axx[i]
    ax.errorbar(var[int(i/3)][int(i%3)][0]*5000, var[int(i/3)][int(i%3)][1], var[int(i/3)][int(i%3)][2])
    ax.set_xlabel('timestep')
    ax.set_ylabel('')
    ax.set_title(titles[int(i%3)]+' - '+labels[int(i/3)]+' PROGRESSIVE MEAN')
    ax.grid()

# %%
fig, axx = plt.subplots(1,3,figsize=(18,6))
for i,ax in enumerate(axx):
    ax.errorbar(gofr_monte[i][0], gofr_monte[i][1], gofr_monte[i][2], label = 'MonteCarlo')
    ax.errorbar(gofr_dyn[i][0], gofr_dyn[i][1], gofr_dyn[i][2], label = 'MolDyn')
    ax.set_xlabel('r')
    ax.set_ylabel(r'$g(r)$')
    ax.set_title(titles[i]+r' $g(r)$')
    ax.grid()
    ax.legend()

# %%
fig, axx = plt.subplots(1,3,figsize=(18,6))
for i,ax in enumerate(axx):
    ax.errorbar(gofr_monte[i][0], gofr_monte[i][1]-gofr_dyn[i][1], np.sqrt(gofr_monte[i][2]**2+gofr_dyn[i][2]**2), label = 'MonteCarlo')
    ax.set_xlabel('r')
    ax.set_ylabel(r'$g(r)$')
    ax.set_title(titles[i]+r' $g(r)$')
    ax.grid()
    ax.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-0c9277a28612> in <module>
#       1 fig, axx = plt.subplots(1,3,figsize=(18,6))
#       2 for i,ax in enumerate(axx):
# ----> 3     ax.errorbar(gofr_monte[i][0], gofr_monte[i][1]-gofr_dyn[i][1], np.sqrt(gofr_monte[i][2]**2+gofr_dyn[i][2]**2), label = 'MonteCarlo')
#       4     ax.set_xlabel('r')
#       5     ax.set_ylabel(r'$g(r)$')
#
# NameError: name 'gofr_monte' is not defined
